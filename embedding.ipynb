# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779093262.907865    9525 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1779093263.961822    9525 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779093267.646002    9525 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
## Sentence
sent = [
  'the glass of milk',
  'the glass of juice',
  'the cup of tea',
  'I am a good boy',
  'I am a good developer',
  'understand the meaning of words',
  'your videos are good'
]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Define the voccabulary size
voc_size =  10000

# %%
### One Hot Representation
one_hot_repr = [one_hot(words, voc_size)for words in sent]
one_hot_repr
# Out:
# [[3188, 2237, 5902, 5310],
#  [3188, 2237, 5902, 3536],
#  [3188, 6095, 5902, 1217],
#  [5887, 4215, 3986, 8236, 600],
#  [5887, 4215, 3986, 8236, 946],
#  [1153, 3188, 2256, 5902, 590],
#  [2525, 5644, 8354, 8236]]

# %%
## Word embedding representation
from tensorflow.keras.layers import Embedding, Input
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 10
embedded_doc = pad_sequences(one_hot_repr, padding='pre', maxlen=sent_length)

print(embedded_doc)
# Out:
# [[   0    0    0    0    0    0 3188 2237 5902 5310]
#  [   0    0    0    0    0    0 3188 2237 5902 3536]
#  [   0    0    0    0    0    0 3188 6095 5902 1217]
#  [   0    0    0    0    0 5887 4215 3986 8236  600]
#  [   0    0    0    0    0 5887 4215 3986 8236  946]
#  [   0    0    0    0    0 1153 3188 2256 5902  590]
#  [   0    0    0    0    0    0 2525 5644 8354 8236]]

# %%
## Feature representation

dim = 10

# %%
model = Sequential([
    Input(shape=(sent_length,)),
    Embedding(input_dim=voc_size, output_dim=dim)
])

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)         │ (None, 10, 10)         │       100,000 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,000 (390.62 KB)
#  Trainable params: 100,000 (390.62 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(embedded_doc)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# array([[[-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [ 0.00125857,  0.02187966, -0.01912066, -0.03797295,
#          -0.03479751, -0.02221285, -0.00261716, -0.01456285,
#          -0.01622554,  0.04094955],
#         [-0.00602329,  0.04625214,  0.00388958, -0.0293892 ,
#          -0.00977272,  0.00390742, -0.01586704, -0.03805702,
#           0.00694013,  0.04786957],
#         [ 0.03512206, -0.02086084,  0.00708433,  0.01615503,
#           0.04436338, -0.01962969,  0.01377194,  0.01196805,
#          -0.01199411,  0.03276009],
#         [ 0.00201067,  0.01295142,  0.04799089, -0.03793914,
#          -0.01160578, -0.04831419, -0.03799526, -0.00491415,
#           0.03635553,  0.04906039]],
#
#        [[-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [ 0.00125857,  0.02187966, -0.01912066, -0.03797295,
#          -0.03479751, -0.02221285, -0.00261716, -0.01456285,
#          -0.01622554,  0.04094955],
#         [-0.00602329,  0.04625214,  0.00388958, -0.0293892 ,
#          -0.00977272,  0.00390742, -0.01586704, -0.03805702,
#           0.00694013,  0.04786957],
#         [ 0.03512206, -0.02086084,  0.00708433,  0.01615503,
#           0.04436338, -0.01962969,  0.01377194,  0.01196805,
#          -0.01199411,  0.03276009],
#         [-0.02012156, -0.02412515,  0.01830873,  0.02485449,
#          -0.02865453,  0.02364968, -0.00203825, -0.02332842,
#          -0.01744901,  0.01230512]],
#
#        [[-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [ 0.00125857,  0.02187966, -0.01912066, -0.03797295,
#          -0.03479751, -0.02221285, -0.00261716, -0.01456285,
#          -0.01622554,  0.04094955],
#         [ 0.00187159,  0.01145529, -0.02948332, -0.01778202,
#           0.02243144,  0.0272512 , -0.04708714, -0.01040347,
#           0.0439973 , -0.01334586],
#         [ 0.03512206, -0.02086084,  0.00708433,  0.01615503,
#           0.04436338, -0.01962969,  0.01377194,  0.01196805,
#          -0.01199411,  0.03276009],
#         [-0.011136  , -0.04281111,  0.03904365,  0.01935171,
#           0.03093537, -0.04502441,  0.00110366,  0.04184187,
#          -0.03631185,  0.00536133]],
#
#        [[-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.00967035, -0.0373034 ,  0.0326901 , -0.03616416,
#          -0.03383823, -0.03003689,  0.04689625, -0.03687968,
#          -0.04871938,  0.00630832],
#         [-0.00038581,  0.04806031, -0.03355885, -0.03537484,
#          -0.00364852,  0.02868916, -0.02608252,  0.03518603,
#           0.00964214,  0.0383927 ],
#         [-0.01015841,  0.00090922,  0.02208439, -0.02112321,
#           0.04210253,  0.01948278, -0.03837053,  0.00875678,
#          -0.04859988,  0.04903856],
#         [-0.01390679,  0.03525821, -0.0244964 , -0.0413986 ,
#           0.02683845,  0.0208712 ,  0.03664244, -0.02918624,
#           0.01915344,  0.03667902],
#         [ 0.01654214, -0.0061639 ,  0.0147344 , -0.02807405,
#          -0.00974634,  0.03136349, -0.02772126, -0.0020204 ,
#          -0.01995122, -0.01445191]],
#
#        [[-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.00967035, -0.0373034 ,  0.0326901 , -0.03616416,
#          -0.03383823, -0.03003689,  0.04689625, -0.03687968,
#          -0.04871938,  0.00630832],
#         [-0.00038581,  0.04806031, -0.03355885, -0.03537484,
#          -0.00364852,  0.02868916, -0.02608252,  0.03518603,
#           0.00964214,  0.0383927 ],
#         [-0.01015841,  0.00090922,  0.02208439, -0.02112321,
#           0.04210253,  0.01948278, -0.03837053,  0.00875678,
#          -0.04859988,  0.04903856],
#         [-0.01390679,  0.03525821, -0.0244964 , -0.0413986 ,
#           0.02683845,  0.0208712 ,  0.03664244, -0.02918624,
#           0.01915344,  0.03667902],
#         [ 0.01505573, -0.00804051, -0.04259746,  0.00303022,
#          -0.04714401, -0.02556565,  0.02942521, -0.01011566,
#          -0.02243582,  0.00659493]],
#
#        [[-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.0084896 ,  0.02597577, -0.00699546,  0.0179213 ,
#           0.03758575, -0.03409912,  0.03742726, -0.01707513,
#           0.039329  , -0.00887456],
#         [ 0.00125857,  0.02187966, -0.01912066, -0.03797295,
#          -0.03479751, -0.02221285, -0.00261716, -0.01456285,
#          -0.01622554,  0.04094955],
#         [-0.03573742, -0.03310126,  0.04409397,  0.04050095,
#          -0.00679977,  0.02039534,  0.04763036,  0.02861924,
#          -0.00628414, -0.02413063],
#         [ 0.03512206, -0.02086084,  0.00708433,  0.01615503,
#           0.04436338, -0.01962969,  0.01377194,  0.01196805,
#          -0.01199411,  0.03276009],
#         [ 0.04451722, -0.03823725, -0.02058108, -0.04430642,
#          -0.04379417, -0.03233709, -0.02674464, -0.04639329,
#           0.03739457,  0.0055501 ]],
#
#        [[-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [-0.04527977, -0.00645746, -0.0081107 ,  0.04959022,
#           0.03504062, -0.00318683,  0.02470173, -0.04326219,
#          -0.0055514 , -0.00820692],
#         [ 0.00623142, -0.01179991, -0.0221255 ,  0.00027428,
#           0.00091001, -0.02397912, -0.04085628,  0.01395658,
#          -0.03152441, -0.03354617],
#         [ 0.04677612, -0.03572606,  0.02808532,  0.01398065,
#           0.04632265,  0.04268397, -0.03847802,  0.01476191,
#           0.00673567,  0.02219918],
#         [ 0.0078309 ,  0.01538548,  0.03740436,  0.0230368 ,
#          -0.00875934,  0.04634304, -0.04463181,  0.02715463,
#           0.00550791, -0.00546532],
#         [-0.01390679,  0.03525821, -0.0244964 , -0.0413986 ,
#           0.02683845,  0.0208712 ,  0.03664244, -0.02918624,
#           0.01915344,  0.03667902]]], dtype=float32)
